# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df = pd.read_csv("resultados_predicao.csv")
df
# Out:
#        API  metrica                        modelo            mae  \
# 0    API 1      CPU     Redes Naurais Recorrentes       0.196776
# 1    API 1   Memory     Redes Naurais Recorrentes       0.081516
# 2    API 1  Request     Redes Naurais Recorrentes   51758.039062
# 3    API 1  Latency     Redes Naurais Recorrentes       0.077906
# 4    API 1      CPU  Redes Naurais Convolucionais       0.294253
# ..     ...      ...                           ...            ...
# 139  API 9  Latency                       XGBoost      17.461673
# 140  API 9      CPU                     AutoArima       1.982744
# 141  API 9   Memory                     AutoArima       0.778461
# 142  API 9  Request                     AutoArima  473368.861637
# 143  API 9  Latency                     AutoArima      18.116113
#
#              rmse   r2_score       tempo
# 0    9.576659e-02   0.674805   42.998556
# 1    1.009674e-02   0.955996   38.451815
# 2    1.405071e+10   0.654855   39.461541
# ...

# %%
df_cpu = df[df['metrica'] == 'CPU']

# %%
df_mem = df[df['metrica'] == 'Memory']

# %%
df_lat = df[df['metrica'] == 'Latency']

# %%
df_req = df[df['metrica'] == 'Request']

# %%
fig, ax = plt.subplots(figsize=(15,5)) 

labels = ["Redes Neurais \nRecorrentes", "Redes Neurais\n Convolucionais", "XGBoost", "AutoArima"]

#Plot 1
plt.subplot(1, 2, 1) 
y1 = df_cpu["r2_score"]

plot1 = sns.barplot(x='modelo',y=y1,data=df_cpu, hue="API") 

plot1.set_xticks(range(4))
plot1.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Coeficiente de determinação (R²)") 
plt.title("Coeficiente de determinação (R²) da CPU por Modelo e Aplicação", loc="center", fontsize=12)
plt.tight_layout() 

#Plot 2
plt.subplot(1, 2, 2) 
y2 = df_cpu["tempo"]

plot2 = sns.barplot(x='modelo',y=y2,data=df_cpu, hue="API") 

plot2.set_xticks(range(4))
plot2.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Tempo de execução (em segundos)") 
plt.title("Tempo de execução da CPU por Modelo e Aplicação", loc="center", fontsize=12) 

plt.tight_layout() 
plt.show()
# Out:
# <ipython-input-193-bb3a5858667a>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)

# %%
fig, ax = plt.subplots(figsize=(15,5)) 

labels = ["Redes Neurais \nRecorrentes", "Redes Neurais\n Convolucionais", "XGBoost", "AutoArima"]

#Plot 1
plt.subplot(1, 2, 1) 
y1 = df_mem["r2_score"]

plot1 = sns.barplot(x='modelo',y=y1,data=df_mem, hue="API") 

plot1.set_xticks(range(4))
plot1.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Coeficiente de determinação (R²)") 
plt.title("Coeficiente de determinação (R²) da Mémoria por Modelo e Aplicação", loc="center", fontsize=12)
plt.tight_layout() 

#Plot 2
plt.subplot(1, 2, 2) 
y2 = df_mem["tempo"]

plot2 = sns.barplot(x='modelo',y=y2,data=df_mem, hue="API") 

plot2.set_xticks(range(4))
plot2.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Tempo de execução (em segundos)") 
plt.title("Tempo de execução da Mémoria por Modelo e Aplicação", loc="center", fontsize=12) 

plt.tight_layout() 
plt.show()
# Out:
# <ipython-input-194-16338337e45f>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)

# %%
fig, ax = plt.subplots(figsize=(15,5)) 

labels = ["Redes Neurais \nRecorrentes", "Redes Neurais\n Convolucionais", "XGBoost", "AutoArima"]

#Plot 1
plt.subplot(1, 2, 1) 
y1 = df_req["r2_score"]

plot1 = sns.barplot(x='modelo',y=y1,data=df_req, hue="API") 

plot1.set_xticks(range(4))
plot1.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Coeficiente de determinação (R²)") 
plt.title("Coeficiente de determinação (R²) da Requisição por Modelo e Aplicação", loc="center", fontsize=12)
plt.tight_layout() 

#Plot 2
plt.subplot(1, 2, 2) 
y2 = df_req["tempo"]

plot2 = sns.barplot(x='modelo',y=y2,data=df_req, hue="API") 

plot2.set_xticks(range(4))
plot2.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Tempo de execução (em segundos)") 
plt.title("Tempo de execução da Requisição por Modelo e Aplicação", loc="center", fontsize=12) 

plt.tight_layout() 
plt.show()
# Out:
# <ipython-input-195-6b03c232a5a7>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)

# %%
fig, ax = plt.subplots(figsize=(15,5)) 

labels = ["Redes Neurais \nRecorrentes", "Redes Neurais\n Convolucionais", "XGBoost", "AutoArima"]

#Plot 1
plt.subplot(1, 2, 1) 
y1 = df_lat["r2_score"]

plot1 = sns.barplot(x='modelo',y=y1,data=df_lat, hue="API") 

plot1.set_xticks(range(4))
plot1.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Coeficiente de determinação (R²)") 
plt.title("Coeficiente de determinação (R²) da Latência por Modelo e Aplicação", loc="center", fontsize=12)
plt.tight_layout() 

#Plot 2
plt.subplot(1, 2, 2) 
y2 = df_lat["tempo"]

plot2 = sns.barplot(x='modelo',y=y2,data=df_lat, hue="API") 

plot2.set_xticks(range(4))
plot2.set_xticklabels(labels)

plt.xlabel("Modelo") 
plt.ylabel("Tempo de execução (em segundos)") 
plt.title("Tempo de execução da Latência por Modelo e Aplicação", loc="center", fontsize=12) 

plt.tight_layout() 
plt.show()
# Out:
# <ipython-input-196-c0398c691780>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
